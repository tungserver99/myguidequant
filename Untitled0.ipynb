# %%
# %cd "/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/GuidedQuant"
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/GuidedQuant

# %%
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 139.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 118.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 105.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 131.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 46.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 127.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 152.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 30.5 MB/s eta 0:00:00
# ...

# %%
# !bash scripts/run_lnq_guidedquant.sh
# Out:
# +++ dirname -- scripts/run_lnq_guidedquant.sh
# ++ cd -- scripts
# ++ pwd
# + SCRIPT_DIR='/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/GuidedQuant/scripts'
# ++ cd -- '/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/GuidedQuant/scripts/..'
# ++ pwd
# + REPO_ROOT='/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/GuidedQuant'
# + cd '/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/GuidedQuant'
# + MODEL_NAME=meta-llama/Llama-2-7b-hf
# + BITS=3
# + NUM_GROUPS=4
# + MODE=pack
# + DATASET=redpajama
# + SEQ_LEN=4096
# + NUM_EXAMPLES=1024
# + MODEL_BASENAME=Llama-2-7b-hf
# + TOKEN_CACHE=cache/tokens/Llama-2-7b-hf-redpajama_s1024_blk4096.pt
# + [[ ! -f cache/tokens/Llama-2-7b-hf-redpajama_s1024_blk4096.pt ]]
# + bash scripts/download_calibration.sh
# + mkdir -p ./cache/tokens
# ...

# %%
# !python eval_ppl.py \
  --model-path cache/layerwise_packed/layerwise-Llama-3.2-1B-w3-c4_s128_blk2048_g4_iter3_cd4 \
  --datasets wikitext2 c4 \
  --seqlen 2048 \
  --method block \
  --dtype fp16 \
  --cache-dir dataset_cache \
  --out-json cache/layerwise_packed/layerwise-Llama-3.2-1B-w3-c4_s128_blk2048_g4_iter3_cd4/ppl_block.json \
  --tag llama32_1b_guidedquant_3bit_c4_128_2048_block
# Out:
# Model:    cache/layerwise_packed/layerwise-Llama-3.2-1B-w3-c4_s128_blk2048_g4_iter3_cd4
# Datasets: ['wikitext2', 'c4']
# Method:   block
# Seqlen:   2048   dtype: fp16
# ------------------------------------------------------------
# 2026-07-27 12:18:16.017447: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-27 12:18:16.084135: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !RANDOM_STATE=42 OVERWRITE=1 bash scripts/run_lnq_guidedquant_llama32_1b_c4_eval_ppl.sh
